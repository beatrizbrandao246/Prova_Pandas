# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizbrandao246/Prova_Pandas/blob/main/Prova_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)
print("Ambiente pronto.")


dados = pd.read_csv ("/content/Avaliação_empresa.csv")

df = pd.DataFrame(dados)

# df.head(5)
# df.info()
# df.columns
# df.describe()
# df[['nome', 'departamento']].head(5)
# df[df['turno']=='Noite']

df
